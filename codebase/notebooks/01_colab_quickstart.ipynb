# %% [markdown]
# # Project 9 – IT Ticket Resolution Recommendation
#
# Colab Quickstart

# %%
import os
os.chdir("/content/ai-ticket-resolution") if os.path.exists("/content/ai-ticket-resolution") else None
print(os.getcwd())

# %%
# !pip install -q -r requirements.txt

# %%
# !python scripts/generate_data.py --n-samples 3000
# !python scripts/train.py

# %%
from src.pipeline.recommender import ResolutionRecommender
r = ResolutionRecommender.load("artifacts")
print(r.recommend(title="Cannot connect to VPN from home",
    description="VPN times out after credentials."))
